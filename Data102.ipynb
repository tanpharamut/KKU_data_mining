# %% [markdown]
# <a href="https://colab.research.google.com/github/tanpharamut/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive') # เชื่อมต่อ drive เพื่อดึงข้อมูล
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# os for ทำงานเกี่ยวกับไฟล์
import os
# pd เพื่อเรียกใช้ตาราง ในไฟล์
import pandas as pd
# สร้างตัวแปลในชื่อ base_path path คือที่ที่เก็บข้อมูลของเราเอง
base_path = '/content/drive/My Drive/DWDM_material'
# เรียกใช้ไฟล์ในโฟเดอร์
data = pd.read_csv(os.path.join(base_path,'test.csv'))
# show เเค่หัวตาราง
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe() #เรียกดูข้อมูล
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# ### Box plot

# %%
from matplotlib import pyplot as plt #import

# %%
plt.boxplot(data['x']) #เรียกดู boxplot ของ x
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f58503af908>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f5850348358>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5850348dd8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f5850348a58>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f58503afc18>,
#   <matplotlib.lines.Line2D at 0x7f58503aff98>]}

# %%
plt.boxplot(data['x'],vert=False) # #เรียกดู boxplot ของ x ในเเนวนอน
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f584fe85f28>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f584fe94978>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f584fe9e438>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f584fe9e0b8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f584fe94278>,
#   <matplotlib.lines.Line2D at 0x7f584fe945f8>]}

# %%
plt.boxplot(data['x'],vert=False,whis=1.2) #เรียกดู boxplot ของ x ในแแนวนอน กำหนด whiskers =1.2 เพื่อให้เห็นค่า error มากขึ้น
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f585030aa20>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f584feb7ef0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f584fe443c8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f585145cc50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f585030a940>,
#   <matplotlib.lines.Line2D at 0x7f585030a5c0>]}

# %% [markdown]
# มีตัวแปรมารับ

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2) # สร้างตัวแปร oput เพื่อเก็บข้อมูล

# %% [markdown]
# 0 เพื่อดึงตัวข้างใน list ออกมา

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['fliers']

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %%
data #เรียกดูข้อมูล
# Out:
#      Unnamed: 0        x        y
# 0             0  55.3846  97.1795
# 1             1  51.5385  96.0256
# 2             2  46.1538  94.4872
# 3             3  42.8205  91.4103
# 4             4  40.7692  88.3333
# ..          ...      ...      ...
# 137         137  39.4872  25.3846
# 138         138  91.2821  41.5385
# 139         139  50.0000  95.7692
# 140         140  47.9487  95.0000
# 141         141  44.1026  92.6923
#
# [142 rows x 3 columns]

# %%
plt.scatter(data['x'],data['y']) # เรียกดูข้อมูล x,y ในรูปของ scatter plot

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='*',alpha=0.4) # เรียกดูข้อมูล x,y ในรูปของ scatter plot โดยให้สีเป็นสีม่วง มีลักษณะเป็นรูปดาว ขนาด 0.4 
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6) #สร้างจุดสีเป็น ตา กับเล็บ ให้ขนาด=0.6

# %% [markdown]
# HW วาด ปีก เเละ นอ ไดโดนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=[data['y']],c='m',marker='*',alpha=0.4) #สร่างหน่อเเละปีกเพิ่ม
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6) 
plt.scatter([75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,90,90,90,90,90,90,90,90,90,90,90,90,90,89.8,89.5,89.4,89.3,89.2,89.1,89,88.9,88.8,88.7,88.6,88.5,88.4,88.3,88.2,88.1,88,87.9,87.8,87.7,87.6,87.5,87.4,87.3,87.2,87.1,87,86.9,86.8,86.7,30,29.9,29.8,29.7,29.6,29.5,29.4,29.3,29.2,29.1,29,28.9,28.8,28.7,28.6,28.5,28.4,28.3,28.2,28.1,28,27.9,27.8,27.7,27.6,27.5,27.5,27.6,27.7,27.8,27.9]
            ,[80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,95,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92])

# %%
plt.plot(data['x'],data['y']) #เรียกดูข้ออมูลในรูปของ plot

# %% [markdown]
# ขีดทีละเส้น

# %%
plt.plot(data['x'],data['y'],'ro-')

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200,c='k') # กำหนดจุดที่เริ่มขีด

# %% [markdown]
# กำหนดขนาดให้เเต่ละจุด เล็กไปใหญ่ตามลำดับการลากเส้น

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=list(range(10,len(data['x'])+10)))

# %% [markdown]
# RGB สี น้ำเงิน(0,0,255) ขาว(255,255,255) แดง(255,0,0) เขียว(0,255,0) เหลือง(255,255,0) ช่องสีสุดท้ายคือ alpha

# %%
plt.scatter(data['x'],data['y'],s=250,c=[[0.2,0.1,0.4,0.5]])

# %%
color_list = []
for i in range(len(data['x'])):
    color_list.append([0.2,0.1,i/255,0.5])
color_list
# Out:
# [[0.2, 0.1, 0.0, 0.5],
#  [0.2, 0.1, 0.00392156862745098, 0.5],
#  [0.2, 0.1, 0.00784313725490196, 0.5],
#  [0.2, 0.1, 0.011764705882352941, 0.5],
#  [0.2, 0.1, 0.01568627450980392, 0.5],
#  [0.2, 0.1, 0.0196078431372549, 0.5],
#  [0.2, 0.1, 0.023529411764705882, 0.5],
#  [0.2, 0.1, 0.027450980392156862, 0.5],
#  [0.2, 0.1, 0.03137254901960784, 0.5],
#  [0.2, 0.1, 0.03529411764705882, 0.5],
#  [0.2, 0.1, 0.0392156862745098, 0.5],
#  [0.2, 0.1, 0.043137254901960784, 0.5],
#  [0.2, 0.1, 0.047058823529411764, 0.5],
#  [0.2, 0.1, 0.050980392156862744, 0.5],
#  [0.2, 0.1, 0.054901960784313725, 0.5],
#  [0.2, 0.1, 0.058823529411764705, 0.5],
#  [0.2, 0.1, 0.06274509803921569, 0.5],
#  [0.2, 0.1, 0.06666666666666667, 0.5],
#  [0.2, 0.1, 0.07058823529411765, 0.5],
#  [0.2, 0.1, 0.07450980392156863, 0.5],
#  [0.2, 0.1, 0.0784313725490196, 0.5],
#  [0.2, 0.1, 0.08235294117647059, 0.5],
#  [0.2, 0.1, 0.08627450980392157, 0.5],
#  [0.2, 0.1, 0.09019607843137255, 0.5],
# ...

# %%
plt.scatter(data['x'],data['y'],s=250,c=color_list)

# %% [markdown]
# ### Bar chart

# %%
import matplotlib # import
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5'] #สร้างตัวแปรเพื่อเก็บข้อมูล
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('scores')
plt.title('Scores by group and gender')
plt.legend();

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# %% [markdown]
# ### Histogram

# %%
x = [12,25,7,7,1,1,1,1,5,5,5,5]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a s d f a s d f s a d f e w r w e f s d f'.split())
# Out:
# (array([5., 4., 0., 4., 0., 5., 2., 0., 2., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)
