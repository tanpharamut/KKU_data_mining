# %% [markdown]
# <a href="https://colab.research.google.com/github/tanpharamut/KKU_data_mining/blob/master/Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas #import

# %% [markdown]
# ### Connect with Google drive

# %%
from google.colab import drive # เชื่อมต่อ drive เพื่อดึงข้อมูล
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/DWDM_material' # สร้างตัวแปลในชื่อ path คือที่ที่เก็บข้อมูลของเราเอง

# %% [markdown]
# ### Create path variables to store where is the data files

# %%
import os

# %%
search_click = os.path.join(path,'search_click.csv') # สร้างตัวแปรเพื่อเก็บข้อมูล
w_restaurant = os.path.join(path,'w_restaurant.csv')

# %% [markdown]
# ### Then use pandas to load the data into the environment

# %%
search_click_df = pandas.read_csv(search_click) #สร้างตัวแปรเพื่อเก็บข้อมูล

# %%
search_click_df.head() #เรียกดูข้อมูล หัวตารางเเละข้อมูลบางตัว
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
w_restaurant_df = pandas.read_csv(w_restaurant) #สร้างตัวแปรเพื่อเก็บข้อมูล

# %%
w_restaurant_df.head()#เรียกดูข้อมูล หัวตารางเเละข้อมูลบางตัว
# Out:
#    id              name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 0   2  นครินทร์ทันตกรรม          2  ...               NaN          NaN      NaN
# 1   4      Corner House          1  ...               NaN          NaN      NaN
# 2   5    วัดโลกยสุธาราม          4  ...               NaN          NaN      NaN
# 3   6    นันท์คาราโอเกะ          1  ...               NaN          NaN      NaN
# 4   7       Buono Caffe          1  ...               NaN          NaN      NaN
#
# [5 rows x 32 columns]

# %%
search_click_df.shape #เรียกดูข้อมูลในรูปแบบของปริมาณ
# Out:
# (1048575, 6)

# %%
w_restaurant_df.shape#เรียกดูข้อมูลในรูปแบบของปริมาณ
# Out:
# (246847, 32)

# %% [markdown]
# ### It seem everything is ok,Let's have fun with data hahaha

# %% [markdown]
# ## 0.Point to data in the table

# %%
search_click_df['search_id'] #เรียกดูข้อมูลของ search_click_df column search_id
# Out:
# 0          5c004472-5ecc-4159-9698-9f329b8e26e1
# 1          5f34eca0-c04e-4c10-b600-54aa447dbd8e
# 2          8dc6d1f0-11f1-4239-9dd2-5c1674c81224
# 3          1a5810e9-3d1f-44b9-9a2e-26ede21c524b
# 4          6bc75e0d-fc65-471e-9926-ff6be6708639
#                            ...
# 1048570    99aab616-6fc5-4fbf-994b-4aebee7bb360
# 1048571    d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a
# 1048572    4c1de7fe-300e-41aa-9d01-914344fc3753
# 1048573    2ec0ddec-e450-4b98-9779-42b77aa7eda5
# 1048574    5741d9cf-b9f1-441d-aa83-d2b0179bf874
# Name: search_id, Length: 1048575, dtype: object

# %%
search_click_df['search_id'][0] #เรียกดูข้อมูลของ search_click_df column search_id ตัวที่ 0
# Out:
# '5c004472-5ecc-4159-9698-9f329b8e26e1'

# %%
w_restaurant_df[['name','city_name','weighted_average_rating']] #เรียกดูข้อมูลของ w_restaurant_df เฉพาะ column name,city_name,weighted_average_rating
# Out:
#                                         name  ... weighted_average_rating
# 0                           นครินทร์ทันตกรรม  ...                5.000000
# 1                               Corner House  ...                2.000000
# 2                             วัดโลกยสุธาราม  ...                4.000000
# 3                             นันท์คาราโอเกะ  ...                0.000000
# 4                                Buono Caffe  ...                3.738462
# ...                                      ...  ...                     ...
# 246842                            Sushi Tama  ...                3.663522
# 246843                     สะบายดี คาราโอเกะ  ...                0.000000
# 246844                      สเต็กแม่&กาแฟลูก  ...                4.000000
# 246845                              Mom Made  ...                5.000000
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง  ...                3.000000
#
# [246847 rows x 3 columns]

# %% [markdown]
# ###.iloc

# %% [markdown]
# ######[แถว,คอลัม]

# %%
search_click_df.iloc[0,1]
# Out:
# '5c004472-5ecc-4159-9698-9f329b8e26e1'

# %% [markdown]
# :10 คือ เริ่มตั้งเเต่ตัวเเรก ถึงตัวที่10 0-9  :2 คือ คอลัม 0 ถึง 1

# %%
search_click_df.iloc[:10,:2]
# Out:
#   click_timestamp                             search_id
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639
# 5         48:16.7  92ea02ba-2c89-4efd-973c-e23526c531de
# 6         39:18.4  79d61918-fb3e-4181-99b6-7a7abddfcdb1
# 7         33:39.0  7f8b2b57-dea1-4fe1-84c8-5a7d63750e47
# 8         07:48.3  3d9217bb-3eae-42b5-8cf3-a756efae2cfa
# 9         41:25.4  a2cb0d41-6e1f-4169-9140-cb671fbb41dc

# %% [markdown]
# ###1 Missing Values

# %%
search_click_df.isnull()
# Out:
#          click_timestamp  search_id  ...  time_diff_nanos    ads
# 0                  False      False  ...            False  False
# 1                  False      False  ...            False  False
# 2                  False      False  ...            False  False
# 3                  False      False  ...            False  False
# 4                  False      False  ...            False  False
# ...                  ...        ...  ...              ...    ...
# 1048570            False      False  ...            False  False
# 1048571            False      False  ...            False  False
# 1048572            False      False  ...            False  False
# 1048573            False      False  ...            False  False
# 1048574            False      False  ...            False  False
#
# [1048575 rows x 6 columns]

# %%
search_click_df.isnull().any() # ตรวจสอบ missing
# Out:
# click_timestamp     False
# search_id            True
# business_id          True
# display_position    False
# time_diff_nanos     False
# ads                 False
# dtype: bool

# %% [markdown]
# ##Handling missing values 1

# %%
search_click_df_nm = search_click_df.dropna()

# %%
search_click_df_nm.isnull().any().any()
# Out:
# False

# %%
print(search_click_df.shape)
print(search_click_df_nm.shape)
# Out:
# (1048575, 6)
# (1048206, 6)

# %% [markdown]
# ## Excercise 1 ตรวจสอบว่า การลบข้อมูล missing ออก
#
# ## จากตาราง w_restarant จะทำให้ข้อมูลลดลงกี่ %

# %%
size_before_drop = w_restaurant_df.shape[0]
size_after_drop = w_restaurant_df.dropna().shape[0]
print(f'size before drop = {size_before_drop} size after drop = {size_after_drop} \nsize after drop = {size_after_drop} \
\nwhich is {100*((size_before_drop-size_after_drop)/size_before_drop)}')
# Out:
# size before drop = 246847 size after drop = 4
# size after drop = 4
# which is 99.99837956304918

# %% [markdown]
# ##Method 1.5

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %%
w_restaurant_df.dropna(subset=['id','name','price_range']).shape #เรียกดูข้อมูลในรูปแบบของปริมาณ
# Out:
# (180972, 32)

# %% [markdown]
# ##Method 2 (raplace with reasonable value)

# %% [markdown]
# ## we are replacing missing value in the number of chains with 0

# %%
w_restaurant_df[['nuber-of_chains']] = w_restaurant_df[['number_of_chains']].fillna(0)

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# Method 2.1 (raplace with unknow value)

# %% [markdown]
# ## Method 3

# %%
new_table = w_restaurant_df[['name' ,'city_name' ,'avg_price']]
new_table
# Out:
#                                         name  ... avg_price
# 0                           นครินทร์ทันตกรรม  ...       NaN
# 1                               Corner House  ...       NaN
# 2                             วัดโลกยสุธาราม  ...       NaN
# 3                             นันท์คาราโอเกะ  ...       NaN
# 4                                Buono Caffe  ...       NaN
# ...                                      ...  ...       ...
# 246842                            Sushi Tama  ...       NaN
# 246843                     สะบายดี คาราโอเกะ  ...       NaN
# 246844                      สเต็กแม่&กาแฟลูก  ...       NaN
# 246845                              Mom Made  ...       NaN
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง  ...       NaN
#
# [246847 rows x 3 columns]

# %% [markdown]
# #[PD] select data

# %% [markdown]
# 1.เลือกเฉพาะกทม. \
# 2.ลบ missing\
# 3.เลือกเฉพาะ column 'avg_price'\
# 4.หา mean

# %%
selected_list = new_table['city_name']=='Bangkok Metropolitan Region' #1.เลือกเฉพาะกทม.
selected_list
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 246842     True
# 246843     True
# 246844     True
# 246845    False
# 246846    False
# Name: city_name, Length: 246847, dtype: bool

# %%
new_table[selected_list].head() #เรียกดูข้อมูล หัวตารางเเละข้อมูลบางตัว
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %%
new_table[new_table['city_name']=='Bangkok Metropolitan Region']
# Out:
#                      name                    city_name  avg_price
# 1            Corner House  Bangkok Metropolitan Region        NaN
# 3          นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4             Buono Caffe  Bangkok Metropolitan Region        NaN
# 7                Sazanami  Bangkok Metropolitan Region        NaN
# 10         Rotee Me Chabu  Bangkok Metropolitan Region        NaN
# ...                   ...                          ...        ...
# 246835     ร้านครัวแกงป่า  Bangkok Metropolitan Region        NaN
# 246840       โตข้าวต้มปลา  Bangkok Metropolitan Region        NaN
# 246842         Sushi Tama  Bangkok Metropolitan Region        NaN
# 246843  สะบายดี คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 246844   สเต็กแม่&กาแฟลูก  Bangkok Metropolitan Region        NaN
#
# [100588 rows x 3 columns]

# %%
new_table[selected_list] #เรียกดูข้อมูล
# Out:
#                      name                    city_name  avg_price
# 1            Corner House  Bangkok Metropolitan Region        NaN
# 3          นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4             Buono Caffe  Bangkok Metropolitan Region        NaN
# 7                Sazanami  Bangkok Metropolitan Region        NaN
# 10         Rotee Me Chabu  Bangkok Metropolitan Region        NaN
# ...                   ...                          ...        ...
# 246835     ร้านครัวแกงป่า  Bangkok Metropolitan Region        NaN
# 246840       โตข้าวต้มปลา  Bangkok Metropolitan Region        NaN
# 246842         Sushi Tama  Bangkok Metropolitan Region        NaN
# 246843  สะบายดี คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 246844   สเต็กแม่&กาแฟลูก  Bangkok Metropolitan Region        NaN
#
# [100588 rows x 3 columns]

# %% [markdown]
# #ราตาเฉลี่ยของราคาในขอนแก่นเท่ากับเท่าไหร่

# %%
avg_price_Khon_Kean = new_table['city_name']=='Khon Kaen'
avg_price_Khon_Kean
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 246842    False
# 246843    False
# 246844    False
# 246845    False
# 246846    False
# Name: city_name, Length: 246847, dtype: bool

# %%
new_table[avg_price_Khon_Kean].head()
# Out:
#                name  city_name  avg_price
# 81      WISH CLINIC  Khon Kaen        NaN
# 317        Pomodoro  Khon Kaen        NaN
# 390      ครัวอรวรรณ  Khon Kaen        NaN
# 452  วาสนาเคียมห้วย  Khon Kaen        NaN
# 514     ส้มตำศิริพร  Khon Kaen        NaN

# %%
new_table[avg_price_Khon_Kean].dropna()
# Out:
# Empty DataFrame
# Columns: [name, city_name, avg_price]
# Index: []

# %% [markdown]
# #ราตาเฉลี่ยของราคาในกรุงเทพเท่ากับเท่าไหร่

# %%
bbk = new_table[new_table['city_name']=='Bangkok Metropolitan Region'].dropna()['avg_price']
bbk
# Out:
# 67         375.0
# 134        175.0
# 247       1500.0
# 319        375.0
# 382        175.0
#            ...
# 246458      50.0
# 246472    1500.0
# 246508     375.0
# 246666     375.0
# 246721     375.0
# Name: avg_price, Length: 3001, dtype: float64

# %%
bbk.mean() # ค่า mean ของ bbk
# Out:
# 392.5854715094968

# %% [markdown]
# #แก้ missing method 3 เติมค่าที่เหมาะสมตามกลุ่มของมัน

# %%
bkk_table = new_table[new_table['city_name']=='Bangkok Metropolitan Region']
bkk_table
# Out:
#                      name                    city_name  avg_price
# 1            Corner House  Bangkok Metropolitan Region        NaN
# 3          นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4             Buono Caffe  Bangkok Metropolitan Region        NaN
# 7                Sazanami  Bangkok Metropolitan Region        NaN
# 10         Rotee Me Chabu  Bangkok Metropolitan Region        NaN
# ...                   ...                          ...        ...
# 246835     ร้านครัวแกงป่า  Bangkok Metropolitan Region        NaN
# 246840       โตข้าวต้มปลา  Bangkok Metropolitan Region        NaN
# 246842         Sushi Tama  Bangkok Metropolitan Region        NaN
# 246843  สะบายดี คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 246844   สเต็กแม่&กาแฟลูก  Bangkok Metropolitan Region        NaN
#
# [100588 rows x 3 columns]

# %%
bkk_table[['avg_price']] = bkk_table[['avg_price']].fillna(bbk.mean()) #แก้ missing method 3 เติมค่าที่เหมาะสมตามกลุ่มของมัน
bkk_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#               name                    city_name   avg_price
# 1     Corner House  Bangkok Metropolitan Region  392.585472
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4      Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7         Sazanami  Bangkok Metropolitan Region  392.585472
# 10  Rotee Me Chabu  Bangkok Metropolitan Region  392.585472

# %%
bkk_table[['avg_price']].fillna(bbk.mean(),inplace=True)
bkk_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#               name                    city_name   avg_price
# 1     Corner House  Bangkok Metropolitan Region  392.585472
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4      Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7         Sazanami  Bangkok Metropolitan Region  392.585472
# 10  Rotee Me Chabu  Bangkok Metropolitan Region  392.585472

# %% [markdown]
# #[PD] ต่อตารางในเเนวเเกน Y (เพิ่มจำนวนdata) pd.concat

# %%
pd_concat = pandas.concat([bkk_table,cm_table])
pd_concat
# Out:
#                            name                    city_name   avg_price
# 1                  Corner House  Bangkok Metropolitan Region  392.585472
# 3                นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4                   Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7                      Sazanami  Bangkok Metropolitan Region  392.585472
# 10               Rotee Me Chabu  Bangkok Metropolitan Region  392.585472
# ...                         ...                          ...         ...
# 246783            ส้มตำลำฮิมกอง                   Chiang Mai  188.415948
# 246803  ไก่ทอดปักษ์ใต้ นายหัวโต                   Chiang Mai  188.415948
# 246808        แคลิฟอร์เนียเวร็ป                   Chiang Mai  188.415948
# 246813   TOONGs COFFEE Roasters                   Chiang Mai  188.415948
# 246826                ลาบเขยยอง                   Chiang Mai  188.415948
#
# [116258 rows x 3 columns]

# %% [markdown]
# #Ex 9 หาราคาเฉลี่ยของร้านในเชียงใหม่

# %%
cm_table = selected_list2 = new_table[new_table['city_name']=='Chiang Mai']
selected_list2
# Out:
#                                 name   city_name  avg_price
# 36                       Wrap Master  Chiang Mai        NaN
# 40                             Sozen  Chiang Mai        NaN
# 52               ไวท์ดราก้อน หมูกะทะ  Chiang Mai        NaN
# 60      เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  Chiang Mai        NaN
# 79                ก๋วยเตี๋ยวเรือสะใจ  Chiang Mai        NaN
# ...                              ...         ...        ...
# 246783                 ส้มตำลำฮิมกอง  Chiang Mai        NaN
# 246803       ไก่ทอดปักษ์ใต้ นายหัวโต  Chiang Mai        NaN
# 246808             แคลิฟอร์เนียเวร็ป  Chiang Mai        NaN
# 246813        TOONGs COFFEE Roasters  Chiang Mai        NaN
# 246826                     ลาบเขยยอง  Chiang Mai        NaN
#
# [15670 rows x 3 columns]

# %%
cm_table_dp = selected_list2.dropna()
cm_table_dp
# Out:
#                                                name   city_name  avg_price
# 196                                   Beer Republic  Chiang Mai      175.0
# 1465    The Riverside Bar & Restaurant @ Chiang Mai  Chiang Mai      375.0
# 2978                   Juice Street Good Belly Cafe  Chiang Mai       50.0
# 4683                       P.P. หมูจุ่ม & กระทะร้อน  Chiang Mai      175.0
# 4918                                     The Duke's  Chiang Mai      175.0
# ...                                             ...         ...        ...
# 243517                                     มนต์นมสด  Chiang Mai       50.0
# 244433                              ก้าวย่างทะเลเผา  Chiang Mai      175.0
# 244841                            ส้มตำปูม้าป้าป่อง  Chiang Mai       50.0
# 244937                                 บ้านหมอนอุ่น  Chiang Mai       50.0
# 245954                                   นาซิ จำปู๋  Chiang Mai      375.0
#
# [464 rows x 3 columns]

# %%
cm_table_dp_avg_price = selected_list2.dropna()['avg_price']
cm_table_dp_avg_price
# Out:
# 196       175.0
# 1465      375.0
# 2978       50.0
# 4683      175.0
# 4918      175.0
#           ...
# 243517     50.0
# 244433    175.0
# 244841     50.0
# 244937     50.0
# 245954    375.0
# Name: avg_price, Length: 464, dtype: float64

# %%
cm_table_dp_avg_price.mean()
# Out:
# 188.41594827586206

# %%
cm_table = new_table[new_table['city_name']=='Chiang Mai']
cm_table[['avg_price']] = cm_table[['avg_price']].fillna(new_table[new_table['city_name']=='Chiang Mai'].dropna()['avg_price'].mean())
cm_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                             name   city_name   avg_price
# 36                   Wrap Master  Chiang Mai  188.415948
# 40                         Sozen  Chiang Mai  188.415948
# 52           ไวท์ดราก้อน หมูกะทะ  Chiang Mai  188.415948
# 60  เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  Chiang Mai  188.415948
# 79            ก๋วยเตี๋ยวเรือสะใจ  Chiang Mai  188.415948

# %%
pd_concat = pandas.concat([bkk_table,cm_table])
pd_concat
# Out:
#                            name                    city_name   avg_price
# 1                  Corner House  Bangkok Metropolitan Region  392.585472
# 3                นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4                   Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7                      Sazanami  Bangkok Metropolitan Region  392.585472
# 10               Rotee Me Chabu  Bangkok Metropolitan Region  392.585472
# ...                         ...                          ...         ...
# 246783            ส้มตำลำฮิมกอง                   Chiang Mai  188.415948
# 246803  ไก่ทอดปักษ์ใต้ นายหัวโต                   Chiang Mai  188.415948
# 246808        แคลิฟอร์เนียเวร็ป                   Chiang Mai  188.415948
# 246813   TOONGs COFFEE Roasters                   Chiang Mai  188.415948
# 246826                ลาบเขยยอง                   Chiang Mai  188.415948
#
# [116258 rows x 3 columns]

# %%
set(new_table['city_name'])
# Out:
# {'Abu Dhabi',
#  'Aichi-ken',
#  'Akershus',
#  'Akita-ken',
#  'Al Farwaniyah Governorate',
#  'Alabama',
#  'Alaska',
#  'Alberta',
#  'Amnat Charoen',
#  'Andalucía',
#  'Ang Thong',
#  'Aomori-ken',
#  'Appenzell Ausserrhoden',
#  'Appenzell Innerrhoden',
#  'Aragón',
#  'Argyll and Bute',
#  'Arizona',
#  'Attica',
#  'Auckland',
#  'Australia',
#  'Auvergne-Rhône-Alpes',
#  'Aydın',
#  'Ba Ria - Vung Tau',
#  'Baden-Wurttemberg',
#  'Bago Region',
#  'Bahia',
#  'Bali',
#  'Balochistan',
#  'Bangkok Metropolitan Region',
#  'Banteay Meanchey Province',
#  'Banten',
#  'Basel-Stadt',
#  'Basilicata',
#  'Basrah',
#  'Battambang',
#  'Bay Of Plenty',
#  'Bayern',
#  'Berlin',
#  'Bern',
#  'Bihar',
#  'Binh Thuan',
#  'Binh Thuan province',
#  'Borno',
#  'Bratislava',
#  'Bremen',
#  'Bretagne',
#  'British Columbia',
#  'Brussels Hoofdstedelijk Gewest',
#  'Buckinghamshire',
#  'Budapest',
#  'Bueng Kan',
#  'Buri Ram',
#  'Busan',
#  'Buskerud',
#  'C2 MALL',
#  'CALABARZON',
# ...

# %%
all_cities = set(new_table['city_name'])
len(all_cities)
# Out:
# 479

# %% [markdown]
# ### 2.คำนวณค่า mean ของ column city_name เพื่อเก็บไว้เติมใส่
# ### เมืองที่เป็น missing ทุกร้าน

# %%
all_mean = new_table.dropna(subset=['avg_price'])['avg_price'].mean()
all_mean
# Out:
# 327.44728783902013

# %% [markdown]
# ###3.สร้าง list ของตารางของทุกๆจังหวัด

# %%
all_cities_list = []
for each_city in list(all_cities):

    temp_table = new_table[new_table['city_name']==each_city].copy()
    temp_table[['avg_price']] = cm_table[['avg_price']].fillna(new_table[new_table['city_name']==each_city].dropna()['avg_price'].mean())
    all_cities_list.append(temp_table)

# %% [markdown]
# ## 4. สร้างตรางจาก list ของตารางด้วย pd.concat

# %%
all_no_missing = pandas.concat(all_cities_list)
all_no_missing
# Out:
#                       name  city_name  avg_price
# 1202    Manyohken Yakiniku   Ōita-ken        NaN
# 9740          Aun , Yufuin   Ōita-ken        NaN
# 10301         Hajime zushi   Ōita-ken        NaN
# 11090               もち吉別府店   Ōita-ken        NaN
# 13818                やよい 店   Ōita-ken        NaN
# ...                    ...        ...        ...
# 186648          Chabu Shin  Gunma-ken        NaN
# 190327   Kinko Chabu-Chabu  Gunma-ken        NaN
# 197603        Sweet & Cafe  Gunma-ken        NaN
# 243377           Katsumune  Gunma-ken        NaN
# 128852  อิ่ม หมูย่างเกาหลี      Kayes        NaN
#
# [246847 rows x 3 columns]

# %%
all_no_missing[all_no_missing['city_name']== 'Chiang Mai']
# Out:
#                                 name   city_name   avg_price
# 36                       Wrap Master  Chiang Mai  188.415948
# 40                             Sozen  Chiang Mai  188.415948
# 52               ไวท์ดราก้อน หมูกะทะ  Chiang Mai  188.415948
# 60      เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  Chiang Mai  188.415948
# 79                ก๋วยเตี๋ยวเรือสะใจ  Chiang Mai  188.415948
# ...                              ...         ...         ...
# 246783                 ส้มตำลำฮิมกอง  Chiang Mai  188.415948
# 246803       ไก่ทอดปักษ์ใต้ นายหัวโต  Chiang Mai  188.415948
# 246808             แคลิฟอร์เนียเวร็ป  Chiang Mai  188.415948
# 246813        TOONGs COFFEE Roasters  Chiang Mai  188.415948
# 246826                     ลาบเขยยอง  Chiang Mai  188.415948
#
# [15670 rows x 3 columns]

# %% [markdown]
# ###5.เติมค่า mean ของทั้งตารางให้กับจังหวัดที่ไม่มี mean

# %%
all_no_missing = all_no_missing.fillna(all_mean)
all_no_missing.isnull().any()
# Out:
# name         False
# city_name    False
# avg_price    False
# dtype: bool

# %% [markdown]
# ### Remove Outlier (boxplot)

# %% [markdown]
# ### Quiz วาด boxplot ของค่า 'avg_price' ของตาราง all_no_missing (แนวนอน)

# %%
from matplotlib import pyplot as plt

# %%
ret = plt.boxplot(all_no_missing['avg_price'],vert=False)

# %%
ret
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f2e3102d8d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2e310186a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2e31051160>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2e31018da0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f2e3102def0>,
#   <matplotlib.lines.Line2D at 0x7f2e31018320>]}

# %%
print(ret['whiskers'][0].get_xdata()[1])
print(ret['whiskers'][1].get_xdata()[1])
# Out:
# 327.44728783902013
# 327.44728783902013

# %%
nooutlier_nomissing = all_no_missing[all_no_missing['avg_price']>=ret['whiskers'][0].get_xdata()[1]]
nooutlier_nomissing = nooutlier_nomissing[nooutlier_nomissing['avg_price']>=ret['whiskers'][1].get_xdata()[1]]
nooutlier_nomissing
# Out:
#                       name  city_name   avg_price
# 1202    Manyohken Yakiniku   Ōita-ken  327.447288
# 9740          Aun , Yufuin   Ōita-ken  327.447288
# 10301         Hajime zushi   Ōita-ken  327.447288
# 11090               もち吉別府店   Ōita-ken  327.447288
# 13818                やよい 店   Ōita-ken  327.447288
# ...                    ...        ...         ...
# 186648          Chabu Shin  Gunma-ken  327.447288
# 190327   Kinko Chabu-Chabu  Gunma-ken  327.447288
# 197603        Sweet & Cafe  Gunma-ken  327.447288
# 243377           Katsumune  Gunma-ken  327.447288
# 128852  อิ่ม หมูย่างเกาหลี      Kayes  327.447288
#
# [231265 rows x 3 columns]

# %% [markdown]
# ### Data Integration

# %% [markdown]
# ### merge two tables (.merge())

# %%
merged_table = search_click_df.merge(w_restaurant_df,how = 'left',left_on='business_id',right_on='id')
merged_table
# Out:
#         click_timestamp  ... nuber-of_chains
# 0               11:38.9  ...            12.0
# 1               30:51.3  ...            28.0
# 2               32:09.6  ...             0.0
# 3               00:59.8  ...             0.0
# 4               23:36.8  ...            28.0
# ...                 ...  ...             ...
# 1048570         05:28.8  ...             0.0
# 1048571         15:28.8  ...             0.0
# 1048572         11:49.4  ...            23.0
# 1048573         10:33.7  ...            12.0
# 1048574         13:51.4  ...             0.0
#
# [1048575 rows x 39 columns]

# %% [markdown]
# ### copy a column from other (.map())

# %%
search_click_df['bu_name'] = search_click_df['business_id'].map(w_restaurant_df.set_index('id')['name'])
search_click_df
# Out:
#         click_timestamp  ...                  bu_name
# 0               11:38.9  ...        ปูดองอันยอง Eight
# 1               30:51.3  ...                Yoshinoya
# 2               32:09.6  ...  The Hub Cafe and Eatery
# 3               00:59.8  ...     ซั่งไห่ เสี่ยวหลงเปา
# 4               23:36.8  ...                Yoshinoya
# ...                 ...  ...                      ...
# 1048570         05:28.8  ...              เสกแจ่วฮ้อน
# 1048571         15:28.8  ...    ก๋วยเตี๋ยวหมูหน่อกะลา
# 1048572         11:49.4  ...      Laemcharoen Seafood
# 1048573         10:33.7  ...     เอี่ยวไถ่ สุกี้โบราณ
# 1048574         13:51.4  ...                  Icy-me
#
# [1048575 rows x 7 columns]

# %%
search_click_df['city'] = search_click_df['business_id'].map(w_restaurant_df.set_index('id')['city_name'])
search_click_df
# Out:
#         click_timestamp  ...                         city
# 0               11:38.9  ...  Bangkok Metropolitan Region
# 1               30:51.3  ...  Bangkok Metropolitan Region
# 2               32:09.6  ...  Bangkok Metropolitan Region
# 3               00:59.8  ...  Bangkok Metropolitan Region
# 4               23:36.8  ...  Bangkok Metropolitan Region
# ...                 ...  ...                          ...
# 1048570         05:28.8  ...                   Chaiyaphum
# 1048571         15:28.8  ...  Bangkok Metropolitan Region
# 1048572         11:49.4  ...  Bangkok Metropolitan Region
# 1048573         10:33.7  ...  Bangkok Metropolitan Region
# 1048574         13:51.4  ...                 Prachin Buri
#
# [1048575 rows x 8 columns]

# %%
search_click_df['weighted_average_rating'] = search_click_df['business_id'].map(w_restaurant_df.set_index('id')['weighted_average_rating'])
search_click_df
# Out:
#         click_timestamp  ... weighted_average_rating
# 0               11:38.9  ...                3.836735
# 1               30:51.3  ...                3.118367
# 2               32:09.6  ...                4.015184
# 3               00:59.8  ...                3.444134
# 4               23:36.8  ...                2.972672
# ...                 ...  ...                     ...
# 1048570         05:28.8  ...                4.000000
# 1048571         15:28.8  ...                4.000000
# 1048572         11:49.4  ...                3.830601
# 1048573         10:33.7  ...                3.766129
# 1048574         13:51.4  ...                3.000000
#
# [1048575 rows x 9 columns]

# %% [markdown]
# ### [PD] groupby()

# %%
search_click_df.groupby('business_id').count()
# Out:
#              click_timestamp  search_id  display_position  ...  ads  bu_name  city
# business_id                                                ...
# 2.0                        4          4                 4  ...    4        4     4
# 5.0                        2          2                 2  ...    2        2     2
# 6.0                        6          6                 6  ...    6        6     6
# 7.0                        3          3                 3  ...    3        3     3
# 14.0                       5          5                 5  ...    5        5     5
# ...                      ...        ...               ...  ...  ...      ...   ...
# 340060.0                   4          4                 4  ...    4        4     4
# 340063.0                   1          1                 1  ...    1        1     1
# 340067.0                   2          2                 2  ...    2        2     2
# 340068.0                   6          6                 6  ...    6        6     6
# ...

# %%
search_click_df.groupby('business_id').count().sort_values('click_timestamp')
# Out:
#              click_timestamp  search_id  display_position  ...   ads  bu_name  city
# business_id                                                ...
# 122473.0                   1          1                 1  ...     1        1     1
# 136485.0                   1          1                 1  ...     1        1     1
# 275120.0                   1          1                 1  ...     1        1     1
# 136492.0                   1          1                 1  ...     1        1     1
# 136498.0                   1          1                 1  ...     1        1     1
# ...                      ...        ...               ...  ...   ...      ...   ...
# 150227.0                1377       1377              1377  ...  1377     1377  1377
# 273486.0                1417       1417              1417  ...  1417     1417  1417
# 112509.0                2130       2130              2130  ...  2130     2130  2130
# ...

# %%
w_restaurant_df[w_restaurant_df['id']==182530.0]
# Out:
#             id      name  domain_id  ...  pet_friendly delivery nuber-of_chains
# 124030  182530  หนานหยวน          1  ...           NaN      NaN             0.0
#
# [1 rows x 33 columns]

# %% [markdown]
# ## QUIZ หาจังหวัดที่มีคน cilck มากที่สุด 3 อันดับเเรก

# %%
search_click_df.groupby('city').count().sort_values('click_timestamp',ascending=False).iloc[:3,:]
# Out:
#                              click_timestamp  search_id  ...     ads  bu_name
# city                                                     ...
# Bangkok Metropolitan Region           596980     596963  ...  596980   596980
# Chiang Mai                             56775      56775  ...   56775    56775
# Chon Buri                              51535      51535  ...   51535    51535
#
# [3 rows x 7 columns]

# %% [markdown]
# ### เฉลย

# %%
search_click_df.groupby('city').count().sort_values('click_timestamp').iloc[-3:,:]
# Out:
#                              click_timestamp  search_id  ...     ads  bu_name
# city                                                     ...
# Chon Buri                              51535      51535  ...   51535    51535
# Chiang Mai                             56775      56775  ...   56775    56775
# Bangkok Metropolitan Region           596980     596963  ...  596980   596980
#
# [3 rows x 7 columns]

# %% [markdown]
# ### เมืองไหนที่มีคต่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด

# %%
search_click_df.groupby('weighted_average_rating').count().sort_values('click_timestamp',ascending=False).iloc[:3,:]
# Out:
#                          click_timestamp  search_id  ...  bu_name    city
# weighted_average_rating                              ...
# 0.0                               106422     106421  ...   106422  106422
# 4.0                                82867      82866  ...    82867   82867
# 3.0                                49659      49659  ...    49659   49659
#
# [3 rows x 8 columns]

# %%
search_click_df.groupby('city').mean().sort_values('weighted_average_rating',ascending=False).iloc[:1,:]
# Out:
#          business_id  display_position  ...  ads  weighted_average_rating
# city                                    ...
# Otago  280996.666667         13.333333  ...  0.0                      5.0
#
# [1 rows x 5 columns]

# %% [markdown]
# ###เฉลย

# %%
w_restaurant_df.head()
# Out:
#    id              name  domain_id  ...  pet_friendly delivery nuber-of_chains
# 0   2  นครินทร์ทันตกรรม          2  ...           NaN      NaN             0.0
# 1   4      Corner House          1  ...           NaN      NaN             0.0
# 2   5    วัดโลกยสุธาราม          4  ...           NaN      NaN             0.0
# 3   6    นันท์คาราโอเกะ          1  ...           NaN      NaN             0.0
# 4   7       Buono Caffe          1  ...           NaN      NaN             0.0
#
# [5 rows x 33 columns]

# %%
w_restaurant_df.groupby('city_name').mean().sort_values('weighted_average_rating',ascending=False)
# Out:
#                                       id  domain_id  ...  delivery  nuber-of_chains
# city_name                                            ...
# Khartoum                   303589.000000        1.0  ...       NaN              0.0
# Cairo Governorate          277711.000000        1.0  ...       NaN              0.0
# Vaud                       161710.500000        1.0  ...       NaN              0.0
# Borno                      276020.000000        2.0  ...       NaN              0.0
# Kepulauan Riau             145430.500000        1.0  ...       NaN              0.0
# ...                                  ...        ...  ...       ...              ...
# Castilla-La Mancha         210336.333333        1.0  ...       NaN              0.0
# Capital Region of Denmark  134835.000000        1.0  ...       NaN              0.0
# Région de Kidal            240208.500000        2.0  ...       NaN              0.0
# ...

# %% [markdown]
# ### เมืองไหนที่มีคต่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด
# ### แบบน่าเชื่อถือ (number_of_reviews สูงที่สุด)

# %%
sorted_star = w_restaurant_df.groupby('city_name').mean().sort_values('weighted_average_rating',ascending=False)
sorted_star
# Out:
#                                       id  domain_id  ...  delivery  nuber-of_chains
# city_name                                            ...
# Khartoum                   303589.000000        1.0  ...       NaN              0.0
# Cairo Governorate          277711.000000        1.0  ...       NaN              0.0
# Vaud                       161710.500000        1.0  ...       NaN              0.0
# Borno                      276020.000000        2.0  ...       NaN              0.0
# Kepulauan Riau             145430.500000        1.0  ...       NaN              0.0
# ...                                  ...        ...  ...       ...              ...
# Castilla-La Mancha         210336.333333        1.0  ...       NaN              0.0
# Capital Region of Denmark  134835.000000        1.0  ...       NaN              0.0
# Région de Kidal            240208.500000        2.0  ...       NaN              0.0
# ...

# %%
sorted_star[sorted_star['number_of_reviews']>=5]
# Out:
#                                         id  ...  nuber-of_chains
# city_name                                   ...
# Maldives                     242953.000000  ...         0.000000
# Chiang Mai                   179078.979643  ...         3.915954
# Bangkok Metropolitan Region  179658.982155  ...        10.122689
# Hua Hin                      180926.866138  ...         6.255330
#
# [4 rows x 28 columns]

# %% [markdown]
# The bast is Maldives

# %% [markdown]
# # Save to use with other applications

# %%
search_click_df.to_csv('search_click_extracted_time.csv')
